# %%
#basic creation of the linkedlist structure

class Node:
    def __init__(self, new_data):
        self.data = new_data
        self.next = None

# Create the first node (head of the list)
head = Node(10)

# Link the second node
head.next = Node(20)

# Link the third node
head.next.next = Node(30)

# Link the fourth node
head.next.next.next = Node(40)

# printing linked list
temp = head
while temp is not None:
    print(temp.data, end=" ")
    temp = temp.next
# Out:
# 10 20 30 40

# %% [markdown]
# insertion at the beginning of the linkedlist

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        

def insert_front(head,data):
    newNode=Node(data)
    newNode.next=head
    return newNode

def printlist(head):
    curr=head
    while curr is not None:
        print(curr.data,end="")
        if curr.next is not None:
            print("->",end="")
        curr=curr.next
    print()
    
if __name__=="__main__":
    head=Node(2)
    head.next=Node(3)
    head.next.next=Node(4)
    head.next.next.next=Node(10)
    
    x=1
    new=insert_front(head,x)
    
    printlist(new)
# Out:
# 1->2->3->4->10

# %% [markdown]
# insertion at the end of the linkedlist

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

def insert_at_end(head,data):
    newNode=Node(data)
    if head is None:
        return newNode
    
    last=head
    
    while last.next is not None:
        last=last.next
        
    last.next=newNode
    
    return head

def printlist(node):
    while node is not None:
        print(node.data,end="")
        if node.next is not None:
            print("->",end="")
        node=node.next
        
    
if __name__ == "__main__":
    # Create a linked list:
    # 1 -> 2 -> 3 -> 4 -> 5
    head = Node(1)
    head.next = Node(2)
    head.next.next = Node(3)
    head.next.next.next = Node(4)
    head.next.next.next.next = Node(5)

    head = insert_at_end(head, 6)

    printlist(head)
# Out:
# 1->2->3->4->5->6

# %% [markdown]
# Deletion at beginning (Removal of first node) in a Linked List

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

def deletehead(head):
    if head is None:
        return None
    temp=head
    head=head.next
    temp=None
    return head
    

def printlist(node):
    while node is not None:
        print(node.data,end="")
        if node.next is not None:
            print("->",end="")
        node=node.next
        
    
if __name__ == "__main__":
    # Create a linked list:
    # 1 -> 2 -> 3 -> 4 -> 5
    head = Node(1)
    head.next = Node(2)
    head.next.next = Node(3)
    head.next.next.next = Node(4)
    head.next.next.next.next = Node(5)

    head = deletehead(head)  
    printlist(head)
# Out:
# 2->3->4->5

# %% [markdown]
# DELETING LAST NODE

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next =None
        
def delete_tail(head):
    if head is None:
        return None
    
    if head.next is None:
        return None
    
    
    secondLast=head
    while secondLast.next.next is not None:
        secondLast=secondLast.next
    
    secondLast.next=None
    return head

def printList(head):
    curr=head
    if curr is not None:
        print(curr.data,end="")
        if curr.next is not None:
            print("->", end="")
        curr=curr.next
        
    return head


if __name__=="__main__":
    head=Node(20)
    head.next=Node(30)
    head.next.next=Node(40)
    head.next.next.next=Node(50)
    
    
    a=delete_tail(head)
    printlist(a)
# Out:
# 20->30->40

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
def delete_at_index(head,x):
    Nodes=[]
    
    curr=head
    while curr is not None:
        Nodes.append(curr)
        curr=curr.next
        
    if x==1:
        temp=head
        head=head.next
        del temp
        return head
    
    prev=Nodes[x-2]
    delNode=Nodes[x-1]
    
    
    prev.next=delNode.next
    del delNode
    
    return head
    
def printList(head):
    curr=head
    if curr is not None:
        print(curr.data,end="")
        if curr.next is not None:
            print("->",end="")
        curr=curr.next
    return head


if __name__=="__main__":
    head=Node(20)
    head.next=Node(30)
    head.next.next=Node(40)
    head.next.next.next=Node(50)
    
    
    a=delete_at_index(head,3)
    printlist(a)
# Out:
# 20->30->50
