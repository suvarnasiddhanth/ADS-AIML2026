# %% [markdown]
# BASIC STUCTURE OF DOUBLY LINKED LIST

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.prev=None
        self.next=None
        
if __name__=="__main__":
    head=Node(10)
    
    head.next=Node(20)
    head.next.prev=head
    
    head.next.next=Node(30)
    head.next.next.prev=head.next
    
    head.next.next.next = Node(40)
    head.next.next.next.prev = head.next.next
    
    curr=head
    while curr is not None:
        print(curr.data,end="")
        if curr.next is not None:
            print("<=>",end="")
            
        curr=curr.next
# Out:
# 10<=>20<=>30<=>40

# %% [markdown]
# FORWARD TARVERSAL ITERATIVE APPROACH

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.prev=None
        self.next=None
        
def forward_traveral_iterative(head):
    curr=head
    while curr is not None:
        print(curr.data,end="")
        curr=curr.next
    print()
    

if __name__=="__main__":
    head=Node(1)
    second=Node(2)
    third=Node(3)
