# %%
class Node:
  def __init__(self,data):
    self.data=data
    self.left=None
    self.right=None

def inorder_traversal_bfs(node):
  if node is None:
    return
  inorder_traversal_bfs(node.left)
  print(node.data,end=' ')
  inorder_traversal_bfs(node.right)

def preorder_traversal_bfs(node):
  if node is None:
    return
  print(node.data,end=' ')
  preorder_traversal_bfs(node.left)
  preorder_traversal_bfs(node.right)


def postorder_traversal_bfs(node):
  if node is None:
    return
  preorder_traversal_bfs(node.left)
  preorder_traversal_bfs(node.right)
  print(node.data,end=' ')


if __name__ == "__main__":
    # Creating the tree
    root = Node(5)
    root.left = Node(3)
    root.right = Node(6)
    root.left.left = Node(2)

    print("In-order DFS: ", end='')
    inorder_traversal_bfs(root)
    print("\nPre-order DFS: ", end='')
    preorder_traversal_bfs(root)
    print("\nPost-order DFS: ", end='')
    postorder_traversal_bfs(root)
# Out:
# In-order DFS: 2 3 5 6
# Pre-order DFS: 5 3 2 6
# Post-order DFS: 3 2 6 5

# %%
from collections import deque


class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


def bfs(root):
    if root is None:
        return

    queue = deque()
    queue.append(root)

    while queue:
        node = queue.popleft()

        print(node.data, end=' ')

        if node.left:
            queue.append(node.left)

        if node.right:
            queue.append(node.right)


if __name__ == "__main__":

    # Creating the tree
    root = Node(5)
    root.left = Node(3)
    root.right = Node(6)
    root.left.left = Node(2)

    print("BFS (Level Order): ", end='')
    bfs(root)
# Out:
# BFS (Level Order): 5 3 6 2

# %%
from collections import deque


class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None


class BST:
    def __init__(self):
        self.root = None

    def insert(self, data):
        if self.root is None:
            self.root = Node(data)
        else:
            self._insert(self.root, data)

    def _insert(self, node, data):
        if data < node.data:
            if node.left is None:
                node.left = Node(data)
            else:
                self._insert(node.left, data)

        elif data > node.data:
            if node.right is None:
                node.right = Node(data)
            else:
                self._insert(node.right, data)

    def search(self, data):
        return self._search(self.root, data)

    def _search(self, node, data):
        if node is None:
            return False

        if node.data == data:
            return True

        if data < node.data:
            return self._search(node.left, data)

        return self._search(node.right, data)

    # Inorder DFS
    def inorder(self, node):
        if node is None:
            return

        self.inorder(node.left)
        print(node.data, end=' ')
        self.inorder(node.right)

    # Preorder DFS
    def preorder(self, node):
        if node is None:
            return

        print(node.data, end=' ')
        self.preorder(node.left)
        self.preorder(node.right)

    # Postorder DFS
    def postorder(self, node):
        if node is None:
            return

        self.postorder(node.left)
        self.postorder(node.right)
        print(node.data, end=' ')

    # BFS / Level Order
    def bfs(self):
        if self.root is None:
            return

        queue = deque([self.root])

        while queue:
            node = queue.popleft()

            print(node.data, end=' ')

            if node.left:
                queue.append(node.left)

            if node.right:
                queue.append(node.right)

# Using the BST


bst = BST()

bst.insert(5)
bst.insert(3)
bst.insert(7)
bst.insert(2)
bst.insert(4)
bst.insert(6)
bst.insert(8)

print("Inorder: ", end='')
bst.inorder(bst.root)

print("\nPreorder: ", end='')
bst.preorder(bst.root)

print("\nPostorder: ", end='')
bst.postorder(bst.root)

print("\nBFS: ", end='')
bst.bfs()

print("\n\nSearch 4:", bst.search(4))
print("Search 10:", bst.search(10))
# Out:
# Inorder: 2 3 4 5 6 7 8
# Preorder: 5 3 2 4 7 6 8
# Postorder: 2 4 3 6 8 7 5
# BFS: 5 3 7 2 4 6 8
#
# Search 4: True
# Search 10: False
