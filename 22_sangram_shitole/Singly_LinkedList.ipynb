# %%
#creating a linklist
class Node:
  def __init__(self,data):
    self.data=data
    self.next=None
  #adding data in the nodes
node1=Node(10)
node2=Node(20)
node3=Node(30)
node4=Node(40)

#adding the address to next node
node1.next=node2
node2.next=node3
node3.next=node4

#assigning the node1 as head and current node as node1 so that we can traverse through whole list
head=node1
current=node1

#traverse until current points to none/null , there are two ways ethier use the boolean way or is not None way
while current:  #while current is not None:
  print(current.data , end="->")
  current=current.next
print("NULL")
# Out:
# 10->20->30->40->NULL

# %%
#Traverse
class Node:
  def __init__(self,data):
    self.data=data
    self.next=None

head=Node(10)
head.next=Node(20)
head.next.next=Node(30)
head.next.next.next=Node(40)

current =head
while current:
  print(current.data, end="->")
  current=current.next
print("NULL")
# Out:
# 10->20->30->40->NULL

# %%
#traversing in linked list in from main fucntion

class Node:
  def __init__(self,data):
    self.data=data
    self.next=None

  def traversal(head):
    while head is not None:
      print(head.data , end="-->")
      head=head.next
    else:
      print("NULL")

  if __name__=="__main__":
    head=Node(10)
    head.next=Node(20)
    head.next.next=Node(30)
    head.next.next.next=Node(40)

    traversal(head)
# Out:
# 10-->20-->30-->40-->NULL

# %%
#Insert at beginning
class Node:
  def __init__(self,data):
    self.data=data
    self.next=None

def insert_at_beginning(head,data):
  new_node=Node(data)
  new_node.next=head
  head=new_node
  return head

def traversal(head):
  if head is None:
    print("Linked List is empty")
  else:
    while head is not None:
      print(head.data , end="-->")
      head=head.next
    print("NULL")

if __name__=="__main__":
  head=None
  print("when we insert only at first")
  head=insert_at_beginning(head,10)
  head=insert_at_beginning(head,20)
  head=insert_at_beginning(head,30)
  head=insert_at_beginning(head,40)
  traversal(head)
  print("when we want to insert at the beginning if there is already a linked list")

  head=insert_at_beginning(head,50)
  head.next=Node(60)
  head.next.next=Node(70)
  head.next.next.next=Node(80)
  traversal(head)
# Out:
# when we insert only at first
# 40-->30-->20-->10-->NULL
# when we want to insert at the beginning if there is already a linked list
# 50-->60-->70-->80-->NULL

# %%
# Insert at End
class Node:
  def __init__(self,data):
    self.data=data
    self.next=None

  def insert_at_end(head,data):
    new_node=Node(data)
    # if the linked list is empyt insert at beginning
    if head is None:
      head=new_node
      return head

    last=head
    while last.next is not None:
      last=last.next

    last.next=new_node
    return head





  def traversal(head):
    if head is None:
      print("Linked List is empty")
    else:
      while head is not None:
        print(head.data , end="-->")
        head=head.next
      print("NULL")

  if __name__=="__main__":
    head=None
    print("when we insert only at first")
    head=Node(10)
    head.next=Node(20)
    head.next.next=Node(30)
    head.next.next.next=Node(40)
    traversal(head)

    print("when we want to insert at the end if there is already a linked list")
    head=insert_at_end(head,50)
    traversal(head)
# Out:
# when we insert only at first
# 10-->20-->30-->40-->NULL
# when we want to insert at the end if there is already a linked list
# 10-->20-->30-->40-->50-->NULL

# %%
#insert at given position
class Node:
    def __init__(self, x):
        self.val = x
        self.next = None

def insertPos(head, pos, val):

    if pos < 1:
        return head

    # head will change if pos = 1
    if pos == 1:
        newNode = Node(val)
        newNode.next = head
        return newNode

    curr = head

    # Traverse to the node just before the new node
    for i in range(1, pos - 1):
        if curr is None:
            return head
        curr = curr.next

    # If position is greater than number of nodes
    if curr is None:
        return head

    newNode = Node(val)

    # update the next pointers
    newNode.next = curr.next
    curr.next = newNode

    return head

def printList(head):
    curr = head
    while curr:
        print(curr.val, end="")
        if curr.next:
            print(" -> ", end="")
        curr = curr.next
    print()

if __name__ == "__main__":
    # Creating the list 1->2->4
    head = Node(1)
    head.next = Node(2)
    head.next.next = Node(4)

    val, pos = 3, 3
    head = insertPos(head, pos, val)
    printList(head)
# Out:
# 1 -> 2 -> 3 -> 4

# %%
'''Problem Statement

Implement a Food Serving System Using Linked Lists

There are N people waiting to be served at two food counters. The people must be served according to their arrival order, so that no person is given an unfair advantage.

The following conditions apply:

The number of people N will always be even.
There are exactly two food counters.
Both counters have the same serving speed.
The people must be divided equally between the two counters.
The first person should be assigned to Counter 1, the second person to Counter 2, the third person to Counter 1, the fourth person to Counter 2, and so on.
The order of people assigned to each counter must be maintained.
Both counters serve their respective people sequentially and simultaneously.
The entire problem must be implemented using Linked Lists only. Do not use Python's built-in lists, queues, stacks, sets, dictionaries, or other data structures.'''



class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


class LinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    # Add a node at the end
    def insert(self, data):
        new_node = Node(data)

        if self.head is None:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node

    # Display the linked list
    def display(self):
        current = self.head

        while current is not None:
            print(current.data, end=" → ")
            current = current.next

        print("None")


# -------------------------------
# 1. Create original linked list
# -------------------------------

n = int(input("Enter number of people: "))

if n % 2 != 0:
    print("Number of people must be even.")
else:

    original = LinkedList()

    for i in range(1, n + 1):
        original.insert("P" + str(i))

    print("\nOriginal Queue:")
    original.display()


    # -------------------------------
    # 2. Create two linked lists
    # -------------------------------

    counter1 = LinkedList()
    counter2 = LinkedList()

    current = original.head
    position = 1

    while current is not None:

        if position % 2 == 1:
            counter1.insert(current.data)
        else:
            counter2.insert(current.data)

        current = current.next
        position += 1


    # -------------------------------
    # 3. Display two counter queues
    # -------------------------------

    print("\nCounter 1 Queue:")
    counter1.display()

    print("\nCounter 2 Queue:")
    counter2.display()


    # -------------------------------
    # 4. Serve people
    # -------------------------------

    print("\nServing Order:")

    current1 = counter1.head
    current2 = counter2.head

    while current1 is not None and current2 is not None:

        print("Counter 1 serves:", current1.data)
        print("Counter 2 serves:", current2.data)

        current1 = current1.next
        current2 = current2.next
# Out:
# Enter number of people: 12
#
# Original Queue:
# P1 → P2 → P3 → P4 → P5 → P6 → P7 → P8 → P9 → P10 → P11 → P12 → None
#
# Counter 1 Queue:
# P1 → P3 → P5 → P7 → P9 → P11 → None
#
# Counter 2 Queue:
# P2 → P4 → P6 → P8 → P10 → P12 → None
#
# Serving Order:
# Counter 1 serves: P1
# Counter 2 serves: P2
# Counter 1 serves: P3
# Counter 2 serves: P4
# Counter 1 serves: P5
# Counter 2 serves: P6
# Counter 1 serves: P7
# Counter 2 serves: P8
# Counter 1 serves: P9
# Counter 2 serves: P10
# Counter 1 serves: P11
# Counter 2 serves: P12

# %%
#delete head
class Node:
  def __init__(self,data):
    self.data=data
    self.next=None

  def delete_head(head):
    if head is None:
      print("Linked List is empty")
    else:
      head=head.next
      return head

  def traversal(head):
    if head is None:
      print("Linked List is empty")
    else:
      while head is not None:
        print(head.data , end="-->")
        head=head.next
      print("NULL")
  if __name__ == "__main__":

    # Create a hard-coded linked list:
    # 8 -> 2 -> 3 -> 1 -> 7
    head = Node(8)
    head.next = Node(2)
    head.next.next = Node(3)
    head.next.next.next = Node(1)
    head.next.next.next.next = Node(7)

    head = delete_head(head)
    printList(head)
# Out:
# 2 -> 3 -> 1 -> 7

# %%
#Delete at end

# %%
class Node:
  def __init__(self,data):
    self.data=data
    self.next=None

  def removeLastNode(head):
    if head is None:
      return None

    if head.next is None:
      return None

    SL=head
    while SL.next.next is not None:
      SL=SL.next

    #delete the last element by making the second last element as the last element
    SL.next=None
    return head


  def printList(head):
    while head is not None:
      print(head.data , end="-->")
      head=head.next
    print("Null")

  if __name__=="__main__":
    head=Node(10)
    head.next=Node(20)
    head.next.next=Node(30)
    head.next.next.next=Node(40)
    head.next.next.next.next=Node(50)

    head=removeLastNode(head)
    printList(head)
# Out:
# 10-->20-->30-->40-->Null
